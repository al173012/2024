# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Multiply, Add
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load dataset MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Function to create attention block
def attention_block(inputs):
    # Global Average Pooling
    attention = GlobalAveragePooling2D()(inputs)
    attention = Dense(inputs.shape[-1], activation='relu')(attention)
    attention = Dense(inputs.shape[-1], activation='sigmoid')(attention)
    attention = tf.expand_dims(tf.expand_dims(attention, 1), 1)

    # Multiply input and attention
    outputs = Multiply()([inputs, attention])
    return outputs

# Function to create the model
def create_model():
    inputs = Input(shape=(28, 28, 1))

    # First convolutional block
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    # Attention block
    x = attention_block(x)

    # Second convolutional block
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    # Attention block
    x = attention_block(x)

    # Flatten and Dense layers
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Create and compile the model
model = create_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc:.4f}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/20
# 750/750 [==============================] - 70s 88ms/step - loss: 0.2224 - accuracy: 0.9317 - val_loss: 0.0871 - val_accuracy: 0.9745
# Epoch 2/20
# 750/750 [==============================] - 69s 92ms/step - loss: 0.0568 - accuracy: 0.9825 - val_loss: 0.0527 - val_accuracy: 0.9852
# Epoch 3/20
# 750/750 [==============================] - 69s 91ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 0.0399 - val_accuracy: 0.9886
# Epoch 4/20
# 750/750 [==============================] - 64s 85ms/step - loss: 0.0266 - accuracy: 0.9914 - val_loss: 0.0438 - val_accuracy: 0.9868
# Epoch 5/20
# 750/750 [==============================] - 65s 87ms/step - loss: 0.0214 - accuracy: 0.9926 - val_loss: 0.0415 - val_accuracy: 0.9882
# Epoch 6/20
# 750/750 [==============================] - 67s 89ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.0409 - val_accuracy: 0.9888
# Epoch 7/20
# 750/750 [==============================] - 66s 88ms/step - loss: 0.0128 - accuracy: 0.9953 - val_loss: 0.0369 - val_accuracy: 0.9908
# Epoch 8/20
# 750/750 [==============================] - 68s 90ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.0390 - val_accuracy: 0.9895
# Epoch 9/20
# 750/750 [==============================] - 65s 87ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.0501 - val_accuracy: 0.9875
# Epoch 10/20
# 750/750 [==============================] - 68s 90ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0441 - val_accuracy: 0.9906
# Epoch 11/20
# 750/750 [==============================] - 69s 92ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0506 - val_accuracy: 0.9906
# Epoch 12/20
# 750/750 [==============================] - 64s 85ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0533 - val_accuracy: 0.9887
# Epoch 13/20
# 750/750 [==============================] - 67s 90ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0446 - val_accuracy: 0.9901
# Epoch 14/20
# 750/750 [==============================] - 64s 85ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0445 - val_accuracy: 0.9907
# Epoch 15/20
# 750/750 [==============================] - 68s 91ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0478 - val_accuracy: 0.9905
# Epoch 16/20
# 750/750 [==============================] - 72s 96ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0487 - val_accuracy: 0.9908
# Epoch 17/20
# 750/750 [==============================] - 66s 87ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0512 - val_accuracy: 0.9908
# Epoch 18/20
# 750/750 [==============================] - 70s 93ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0545 - val_accuracy: 0.9898
# Epoch 19/20
# 750/750 [==============================] - 71s 95ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0498 - val_accuracy: 0.9898
# Epoch 20/20
# 750/750 [==============================] - 67s 89ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0518 - val_accuracy: 0.9905
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0469 - accuracy: 0.9895
# Test accuracy: 0.9895

# %%
from graphviz import Digraph

dot = Digraph(comment='Research Flowchart')

# Langkah-langkah penelitian
dot.node('A', 'Start')
dot.node('B', 'Literature Review')
dot.node('C', 'Define Problem and Objectives')
dot.node('D', 'Data Collection (MNIST)')
dot.node('E', 'Preprocessing Data')
dot.node('F', 'Build Attention Model')
dot.node('G', 'Train Model')
dot.node('H', 'Evaluate Model')
dot.node('I', 'Result Analysis and Conclusion')
dot.node('J', 'End')

# Hubungan antar langkah
dot.edges(['AB', 'BC', 'CD', 'DE', 'EF', 'FG', 'GH', 'HI', 'IJ'])

# Menyimpan dan menampilkan diagram
dot.render('research_flowchart', format='png', view=True)
# Out:
# 'research_flowchart.png'
